# %%
import pandas as pd
import matplotlib.pyplot as  plt 
plt.rcParams['font.sans-serif'] = ["WenQuanYi Zen Hei"]
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_excel(r"附件/IT行业收入表.xlsx")
X = df[['工龄']]
Y = df['薪水']

plt.scatter(X,Y)
plt.xlabel('年龄')
plt.ylabel('薪水')
# Out:
# findfont: Failed to find font weight normal, now using 500.
# Text(0, 0.5, '薪水')

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(X,Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,Y)
plt.plot(X,regr.predict(X),color='red')
plt.xlabel('年龄')
plt.ylabel('薪水')
# Out:
# Text(0, 0.5, '薪水')

# %%
print('系数a:'+ str(regr.coef_[0]))
print('截距b:' + str(regr.intercept_))
# Out:
# 系数a:2497.1513476046866
# 截距b:10143.131966873787

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_regr = PolynomialFeatures(degree=2)
X_ = poly_regr.fit_transform(X)

regr = LinearRegression()
regr.fit(X_,Y)
plt.scatter(X,Y)
plt.plot(X,regr.predict(X_),color='blue')
plt.grid()

# %%
import statsmodels.api as sm
X2 = sm.add_constant(X_)
est = sm.OLS(Y,X2).fit()
est.summary()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import statsmodels.api as sm
#       2 X2 = sm.add_constant(X_)
#       3 est = sm.OLS(Y,X2).fit()
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
from sklearn.metrics import r2_score
r2 = r2_score(Y,regr.predict(X_))
print('R2 score: %.2f' % r2)
# Out:
# R2 score: 0.93

# %%
df = pd.read_excel(r'D:\Users\ruixiang\Desktop\客户价值数据表.xlsx')
df
# Out:
#      客户价值  历史贷款金额  贷款次数  学历    月收入  性别
# 0    1150    6488     2   2   9567   1
# 1    1157    5194     4   2  10767   0
# 2    1163    7066     3   2   9317   0
# 3     983    3550     3   2  10517   0
# 4    1205    7847     3   3  11267   1
# ..    ...     ...   ...  ..    ...  ..
# 123  1224    7018     3   3  10117   0
# 124  1518    5904     4   3  11417   1
# 125  1140    7089     2   2  10967   1
# 126  1510    5215     3   3  10717   1
# 127  1281    4353     3   3  11867   0
#
# [128 rows x 6 columns]

# %%
X = df[['贷款次数','学历','月收入']]
Y = df['客户价值']

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(X,Y)
# Out:
# LinearRegression()

# %%
print('各系数：'+str(regr.coef_))
print('截距：'+str(regr.intercept_))
# Out:
# 各系数：[1.03956978e+02 1.40239957e+02 7.18029735e-02]
# 截距：-96.10200323331219

# %%
X2 = sm.add_constant(X)
est = sm.OLS(Y,X2).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   客户价值   R-squared:                       0.446
# Model:                            OLS   Adj. R-squared:                  0.433
# Method:                 Least Squares   F-statistic:                     33.27
# Date:                Thu, 28 May 2026   Prob (F-statistic):           7.59e-16
# Time:                        13:33:18   Log-Likelihood:                -859.83
# No. Observations:                 128   AIC:                             1728.
# Df Residuals:                     124   BIC:                             1739.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -96.1020    182.686     -0.526      0.600    -457.690     265.486
# ...

# %%
import numpy as np
x = np.linspace(-6,6)
y = 1.0 / (1.0 + np.exp(-x))
plt.plot(x,y)

# %%
X = [[1,0],[5,1],[6,4],[4,2],[3,2]]
Y = [0,1,1,0,0]

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X,Y)
# Out:
# LogisticRegression()

# %%
model.predict([[2,2]])
# Out:
# array([0])

# %%
y_pred_prob = model.predict_proba(X)
a = pd.DataFrame(y_pred_prob,columns=['P(Y=0)','P(Y=1)'])
a
# Out:
#      P(Y=0)    P(Y=1)
# 0  0.973459  0.026541
# 1  0.390757  0.609243
# 2  0.179889  0.820111
# 3  0.631706  0.368294
# 4  0.824269  0.175731

# %%
print('各系数：'+str(model.coef_))
print('截距：'+str(model.intercept_))
# Out:
# 各系数：[[1.00599764 0.02232318]]
# 截距：[-4.60818025]
